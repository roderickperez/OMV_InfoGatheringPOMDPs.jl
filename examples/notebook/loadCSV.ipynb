# %% [markdown]
# # Open CSV files

# %%
# Install libraries
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import pandas as pd

# %%
# Define a function to load CSV file
def loadCSV(filename):
    df = pd.read_csv(filename)
    # Return dataset
    return df

# %%
data = loadCSV('/workspaces/OMV_InfoGatheringPOMDPs.jl/examples/data/Geothermal Reservoir/DSSCEN1_50N_POMDP.csv')

# %%
data.head()
# Out:
#                    RUN     SAMPLING         NPV      par_AZ  par_C_ROCK  \
# 0  DS1_400_250_BC_EN_1  DS1_400_250 -415.542188  146.582613    0.000067
# 1  DS1_400_250_BC_EN_1  DS1_400_250   -9.294734  146.582613    0.000067
# 2  DS1_400_250_BC_EN_1  DS1_400_250 -418.994894  146.582613    0.000067
# 3  DS1_400_250_BC_EN_1  DS1_400_250   16.807552  146.582613    0.000067
# 4  DS1_400_250_BC_EN_1  DS1_400_250  145.448033  146.582613    0.000067
#
#    par_C_WATER   par_FTM  par_HCAP_OB  par_HCAP_RES  par_HCAP_UB  ...  \
# 0     0.000047  0.039205         3070   2948.865042         2930  ...
# 1     0.000047  0.039205         3070   2948.865042         2930  ...
# 2     0.000047  0.039205         3070   2948.865042         2930  ...
# 3     0.000047  0.039205         3070   2948.865042         2930  ...
# 4     0.000047  0.039205         3070   2948.865042         2930  ...
#
#    par_CAPEXitem3  par_CAPEXitem4  par_CAPEXitem5  par_CAPEXitem6  \
# ...
